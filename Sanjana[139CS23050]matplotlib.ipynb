# %% [markdown]
# # Matplotlib Tutorial

# %% [markdown]
# # What is Matplotlib?
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %% [markdown]
# # Matplotlib Getting Started

# %% [markdown]
# # Installation of Matplotlib
# If you have Python and PIP already installed on a system, then installation of Matplotlib is very easy.
#
# Install it using this command:
#
# C:\Users\Your Name>pip install matplotlib

# %% [markdown]
# # Import Matplotlib
# Once Matplotlib is installed, import it in your applications by adding the import module statement:

# %%
import matplotlib

# %% [markdown]
# # Checking Matplotlib Version
# The version string is stored under __version__ attribute.

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.2.2

# %% [markdown]
# # Matplotlib Pyplot

# %% [markdown]
# # Pyplot
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Plotting

# %% [markdown]
# # Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Plotting Without Line
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# # Multiple Points
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Default X-Points
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %% [markdown]
# # Markers
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# # using '*'

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,4,12,23,25])
plt.plot(ypoints,marker='*')
plt.show()

# %% [markdown]
# # Format Strings fmt
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([4,2,5,7])
plt.plot(ypoints,'o:b')
plt.show()

# %% [markdown]
# # Marker Size
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([5,6,3,4])
plt.plot(ypoints, marker='o',ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([2,3,5,7])
plt.plot(ypoints,marker='o',ms=30,mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([5,7,2,3])
plt.plot(ypoints,marker='o',ms=30,mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([8,3,9,5])
plt.plot(ypoints,marker='o',ms=20,mfc='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([7,4,8,3])
plt.plot(ypoints,marker='o',ms=30,mec='g',mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([8,5,4,3])
plt.plot(ypoints,marker='o',ms=20,mec='#4CAF50',mfc='#4CAF50')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([5,8,6,4])
plt.plot(ypoints,marker='o',ms=30,mec='hotpink',mfc='hotpink')
plt.show()

# %% [markdown]
# # Matplotlib Line

# %% [markdown]
# # Linestyle
# You can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([8,2,5,6])
plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([8,5,6,9])
plt.plot(ypoints,linestyle='dashed')
plt.show()

# %% [markdown]
# # Shorter Syntax
# The line style can be written in a shorter syntax:
#
# linestyle can be written as ls.
#
# dotted can be written as :.
#
# dashed can be written as --.

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([8,2,6,4])
plt.plot(ypoints,ls=':')
plt.show()

# %% [markdown]
# # Line Color
# You can use the keyword argument color or the shorter c to set the color of the line:

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([5,6,2,3,4])
plt.plot(ypoints,color='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([5,2,3,6])
plt.plot(ypoints,color='hotpink')
plt.show()

# %% [markdown]
# # Line Width
# You can use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number, in points:

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([5,2,4,9])
plt.plot(ypoints,linewidth=20.0)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([8,2,6,3])
plt.plot(ypoints,color='r',linewidth=20.0)
plt.show()

# %% [markdown]
# # Multiple Lines
# You can plot as many lines as you like by simply adding more plt.plot() functions:

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([8,2,6,3])
y2=np.array([5,9,3,6])
plt.plot(y1,color='g')
plt.plot(y2,color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=([5,2,6,4])
y1=([8,6,4,2])
x2=([5,6,2,3])
y2=([6,2,4,9])
plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %% [markdown]
# # Create Labels for a Plot
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([5,6,8,2])
ypoints=np.array([4,2,3,5])
plt.plot(xpoints,ypoints)
plt.xlabel("sales")
plt.ylabel("duration")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,4,2,3])
y=np.array([2,3,4,8])
plt.plot(x,y)
plt.title("marketting")
plt.xlabel("sales")
plt.ylabel("durations")
plt.show()

# %% [markdown]
# # Set Font Properties for Title and Labels
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,2,6,4])
y=np.array([8,5,6,7])
font1={'color':'red','size':20}
font2={'color':'hotpink','size':15}
plt.title("marketting",fontdict=font1)
plt.xlabel("sales",fontdict=font2)
plt.ylabel("duration",fontdict=font2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Position the Title
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([4,5,2,4])
y=np.array([8,2,3,4])
plt.title("marketting",loc='left')
plt.xlabel("sales")
plt.ylabel("duration")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %% [markdown]
# # Add Grid Lines to a Plot
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,4,5,2])
y=np.array([5,12,3,6])
plt.title("marketting")
plt.xlabel("sales")
plt.ylabel("duration")
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# # Specify Which Grid Lines to Display
# You can use the axis parameter in the grid() function to specify which grid lines to display.
#
# Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,2,4,6])
y=np.array([4,2,5,6])
plt.title("marketting")
plt.xlabel("sales")
plt.ylabel("duration")
plt.plot(x,y)
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,4,6,9])
y=np.array([8,9,5,4])
plt.title("marketting")
plt.xlabel("sales")
plt.ylabel("duration")
plt.plot(x,y)
plt.grid(axis='x')
plt.show()

# %% [markdown]
# # Set Line Properties for the Grid
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,5,6,4])
y=np.array([4,2,6,8])
plt.title("marketting")
plt.xlabel("sales")
plt.ylabel("duration")
plt.plot(x,y)
plt.grid(color='green',linestyle='dashed',linewidth=0.50)
plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %% [markdown]
# # Display Multiple Plots
# With the subplot() function you can draw multiple plots in one figure:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,6,9,2])
y=np.array([8,4,2,6])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([4,6,8,9])
y=np.array([6,2,4,4])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # The subplot() Function
# The subplot() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.
#
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,7,6,4])
y=np.array([4,8,6,4])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([4,8,7,2])
y=np.array([4,5,2,6])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,7,2,6])
y=np.array([4,2,8,6])
plt.subplot(2,3,1)
plt.plot(x,y)
x=np.array([8,4,6,7])
y=np.array([4,2,8,6])
plt.subplot(2,3,2)
plt.plot(x,y)
x=np.array([2,4,1,5])
y=np.array([1,5,9,4])
plt.subplot(2,3,3)
plt.plot(x,y)
x=np.array([8,4,3,5])
y=np.array([3,5,7,1])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Title
# You can add a title to each plot with the title() function:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,5,9,6])
y=np.array([4,8,6,2])
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title("SALES")
x=np.array([7,5,3,6])
y=np.array([9,4,3,7])
plt.subplot(2,2,2)
plt.plot(x,y)
plt.title("INCOME")
plt.show()

# %% [markdown]
# # Super Title
# You can add a title to the entire figure with the suptitle() function:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([24,2,96,4])
y=np.array([4,8,9,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("INCOME")
x=np.array([12,10,14,13])
y=np.array([20,21,25,4])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("SALES")
plt.suptitle("STORE")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %% [markdown]
# # Creating Scatter Plots
# With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,4,2,3,4,8,6])
y=np.array([15,2,4,6,8,2,8])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,15,1,6])
y=np.array([14,18,19,4])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Compare Plots
# In the example above, there seems to be a relationship between speed and age, but what if we plot the observations from another day as well? Will the scatter plot tell us something else?

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([41,52,63,42])
y=np.array([12,14,54,62])
plt.scatter(x,y)
x=np.array([54,2,56,84,42])
y=np.array([45,21,47,84,56])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Colors
# You can set your own color for each scatter plot with the color or the c argument:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([4,1,52,62,43])
y=np.array([78,45,96,52,22])
plt.scatter(x,y,color='green')
x=np.array([54,69,85,75])
y=np.array([12,14,25,22])
plt.scatter(x,y,color='red')
plt.show()

# %% [markdown]
# # Color Each Dot
# You can even set a specific color for each dot by using an array of colors as value for the c argument:
#
# Note: You cannot use the color argument for this, only the c argument.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([42,26,24,52])
y=np.array([78,45,95,68])
color=np.array(["green","red","blue","purple"])
plt.scatter(x,y,c=color)
plt.show()

# %% [markdown]
# # ColorMap
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color.
#
# How to Use the ColorMap
# You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([48,12,26,45,78,85,95,65,85,96,45,75,25])
y=np.array([45,65,89,24,52,45,85,96,52,63,42,52,48])
color=np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])
plt.scatter(x,y,c=color,cmap='viridis')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([48,12,26,45,78,85,95,65,85,96,45,75,25])
y=np.array([45,65,89,24,52,45,85,96,52,63,42,52,48])
color=np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])
plt.scatter(x,y,c=color,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# # Size
# You can change the size of the dots with the s argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %%
import matplotlib.pyplot as plt
import numpy as np 
x=np.array([10,52,2,6,58])
y=np.array([45,48,75,95,62])
size=np.array([10,150,14,16,100])
plt.scatter(x,y,s=size)
plt.show()

# %% [markdown]
# # Alpha
# You can adjust the transparency of the dots with the alpha argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %%
import matplotlib.pyplot as plt
import numpy as np 
x=np.array([10,52,2,6,58])
y=np.array([45,48,75,95,62])
size=np.array([10,150,14,16,100])
plt.scatter(x,y,s=size,alpha=0.50)
plt.show()

# %% [markdown]
# # Combine Color Size and Alpha
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
color=np.random.randint(100,size=(100))
size=10*np.random.randint(100,size=(100))
plt.scatter(x,y,c=color,s=size,alpha=0.50,cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# # Matplotlib Bars

# %% [markdown]
# # Creating Bars
# With Pyplot, you can use the bar() function to draw bar graphs:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y)
plt.show()

# %% [markdown]
# # Bar Color
# The bar() and barh() take the keyword argument color to set the color of the bars:

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array(["A","B","C","D"])
y=np.array([4,2,8,6])
plt.barh(x,y,color='red')
plt.show()

# %% [markdown]
# # Bar Width
# The bar() takes the keyword argument width to set the width of the bars:

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array()
